# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import requests
import time
import json
from citipy import citipy
from datetime import datetime
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | leningradskiy
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | dabhol
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | petatlan
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | vestmannaeyjar
# Processing Record 14 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | mayo
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | nagua
# Processing Record 19 of Set 1 | roma
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | baoning
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | skibbereen
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | cayenne
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | hokitika
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | prince rupert
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | kijang
# Processing Record 39 of Set 1 | benguela
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | baykit
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | greensburg
# Processing Record 49 of Set 1 | lake city
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | juneau
# Processing Record 2 of Set 2 | brae
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | humaita
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | tigre
# Processing Record 7 of Set 2 | surgut
# Processing Record 8 of Set 2 | kibre mengist
# Processing Record 9 of Set 2 | venado tuerto
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | nenjiang
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 20 of Set 2 | belmonte
# Processing Record 21 of Set 2 | arequipa
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | nam tha
# City not found. Skipping...
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | neuquen
# Processing Record 26 of Set 2 | eniwa
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | hare bay
# Processing Record 29 of Set 2 | rabo de peixe
# Processing Record 30 of Set 2 | richards bay
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 2 | giyani
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | poum
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | san policarpo
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | lumberton
# Processing Record 41 of Set 2 | kafue
# Processing Record 42 of Set 2 | evans
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | winslow
# Processing Record 45 of Set 2 | pando
# Processing Record 46 of Set 2 | son la
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | codrington
# Processing Record 49 of Set 2 | emba
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | namibe
# Processing Record 5 of Set 3 | hervey bay
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | novopokrovka
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | puerto escondido
# Processing Record 12 of Set 3 | havoysund
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 3 | denpasar
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | belaya gora
# Processing Record 20 of Set 3 | fort morgan
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | yemelyanovo
# Processing Record 27 of Set 3 | hearst
# Processing Record 28 of Set 3 | kamariotissa
# Processing Record 29 of Set 3 | aswan
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | maniwaki
# Processing Record 32 of Set 3 | abalak
# Processing Record 33 of Set 3 | calama
# Processing Record 34 of Set 3 | gat
# Processing Record 35 of Set 3 | klaeng
# Processing Record 36 of Set 3 | bad hofgastein
# Processing Record 37 of Set 3 | maraba
# Processing Record 38 of Set 3 | seymchan
# Processing Record 39 of Set 3 | rafai
# Processing Record 40 of Set 3 | okha
# Processing Record 41 of Set 3 | graulhet
# Processing Record 42 of Set 3 | rosehearty
# Processing Record 43 of Set 3 | placido de castro
# Processing Record 44 of Set 3 | tonj
# Processing Record 45 of Set 3 | albion
# Processing Record 46 of Set 3 | staraya russa
# Processing Record 47 of Set 3 | upernavik
# Processing Record 48 of Set 3 | bahar
# Processing Record 49 of Set 3 | vigrestad
# Processing Record 50 of Set 3 | lorengau
# Processing Record 1 of Set 4 | impfondo
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | cortes
# Processing Record 5 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 4 | luba
# Processing Record 7 of Set 4 | krasnozerskoye
# Processing Record 8 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 4 | caetite
# Processing Record 11 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 4 | kearney
# Processing Record 13 of Set 4 | pyu
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | kuruman
# Processing Record 16 of Set 4 | grand gaube
# Processing Record 17 of Set 4 | gushikawa
# Processing Record 18 of Set 4 | chancay
# Processing Record 19 of Set 4 | am timan
# Processing Record 20 of Set 4 | qaanaaq
# Processing Record 21 of Set 4 | kirakira
# Processing Record 22 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 4 | naryan-mar
# Processing Record 24 of Set 4 | dalbandin
# Processing Record 25 of Set 4 | santa cruz
# Processing Record 26 of Set 4 | magadan
# Processing Record 27 of Set 4 | astoria
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | fort abbas
# Processing Record 30 of Set 4 | douglas
# Processing Record 31 of Set 4 | waipawa
# Processing Record 32 of Set 4 | katobu
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | trapani
# Processing Record 35 of Set 4 | port macquarie
# Processing Record 36 of Set 4 | kapaa
# Processing Record 37 of Set 4 | tazovskiy
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | batagay-alyta
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | dolores
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | acarau
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | honiara
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | kamenka
# Processing Record 1 of Set 5 | santa catarina pinula
# Processing Record 2 of Set 5 | surt
# Processing Record 3 of Set 5 | penon blanco
# Processing Record 4 of Set 5 | acapulco
# Processing Record 5 of Set 5 | avarua
# Processing Record 6 of Set 5 | gouyave
# Processing Record 7 of Set 5 | qurayyat
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | nuuk
# Processing Record 10 of Set 5 | ketchikan
# Processing Record 11 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 5 | turukhansk
# Processing Record 13 of Set 5 | longyearbyen
# Processing Record 14 of Set 5 | zlobin
# Processing Record 15 of Set 5 | nokaneng
# Processing Record 16 of Set 5 | trincomalee
# Processing Record 17 of Set 5 | kungurtug
# Processing Record 18 of Set 5 | tautira
# Processing Record 19 of Set 5 | mitsamiouli
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | saint-joseph
# Processing Record 22 of Set 5 | sinnamary
# Processing Record 23 of Set 5 | thompson
# Processing Record 24 of Set 5 | laguna
# Processing Record 25 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 26 of Set 5 | bubaque
# Processing Record 27 of Set 5 | clyde
# Processing Record 28 of Set 5 | encruzilhada do sul
# Processing Record 29 of Set 5 | fortuna
# Processing Record 30 of Set 5 | hayden
# Processing Record 31 of Set 5 | mugur-aksy
# Processing Record 32 of Set 5 | jinxi
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | quelimane
# Processing Record 35 of Set 5 | sivaki
# Processing Record 36 of Set 5 | makat
# Processing Record 37 of Set 5 | urma
# Processing Record 38 of Set 5 | severo-kurilsk
# Processing Record 39 of Set 5 | leh
# Processing Record 40 of Set 5 | beyneu
# Processing Record 41 of Set 5 | bandar-e lengeh
# Processing Record 42 of Set 5 | antofagasta
# Processing Record 43 of Set 5 | elizabeth city
# Processing Record 44 of Set 5 | turtas
# Processing Record 45 of Set 5 | bud
# Processing Record 46 of Set 5 | praxedis guerrero
# Processing Record 47 of Set 5 | clyde river
# Processing Record 48 of Set 5 | arlit
# Processing Record 49 of Set 5 | garowe
# Processing Record 50 of Set 5 | fare
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | nabire
# Processing Record 3 of Set 6 | tuntum
# Processing Record 4 of Set 6 | waitati
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | batagay
# Processing Record 7 of Set 6 | buta
# Processing Record 8 of Set 6 | rafraf
# Processing Record 9 of Set 6 | butembo
# Processing Record 10 of Set 6 | puerto leguizamo
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | dikson
# Processing Record 13 of Set 6 | belem de sao francisco
# Processing Record 14 of Set 6 | zaragoza
# Processing Record 15 of Set 6 | mehamn
# Processing Record 16 of Set 6 | faya
# Processing Record 17 of Set 6 | kualakapuas
# Processing Record 18 of Set 6 | rio grande
# Processing Record 19 of Set 6 | panama city
# Processing Record 20 of Set 6 | yichun
# Processing Record 21 of Set 6 | kongoussi
# Processing Record 22 of Set 6 | chipinge
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | jalu
# Processing Record 25 of Set 6 | nouadhibou
# Processing Record 26 of Set 6 | mutum
# Processing Record 27 of Set 6 | santiago del estero
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | toowoomba
# Processing Record 32 of Set 6 | whitehorse
# Processing Record 33 of Set 6 | bandarbeyla
# Processing Record 34 of Set 6 | shache
# Processing Record 35 of Set 6 | yeppoon
# Processing Record 36 of Set 6 | ahuimanu
# Processing Record 37 of Set 6 | mazagao
# Processing Record 38 of Set 6 | nowy dwor gdanski
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | college
# Processing Record 41 of Set 6 | tezu
# Processing Record 42 of Set 6 | georgetown
# Processing Record 43 of Set 6 | iqaluit
# Processing Record 44 of Set 6 | grootfontein
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | toropets
# Processing Record 47 of Set 6 | rosarito
# Processing Record 48 of Set 6 | alihe
# Processing Record 49 of Set 6 | shcholkine
# City not found. Skipping...
# Processing Record 50 of Set 6 | cap malheureux
# Processing Record 1 of Set 7 | mogadishu
# Processing Record 2 of Set 7 | san cristobal
# Processing Record 3 of Set 7 | raul soares
# Processing Record 4 of Set 7 | port moresby
# Processing Record 5 of Set 7 | husavik
# Processing Record 6 of Set 7 | shira
# Processing Record 7 of Set 7 | pitmedden
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | avera
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | itacare
# Processing Record 12 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 7 | jiwani
# Processing Record 14 of Set 7 | vostok
# Processing Record 15 of Set 7 | scunthorpe
# Processing Record 16 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 7 | beloha
# Processing Record 18 of Set 7 | barinas
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | bandipur
# Processing Record 21 of Set 7 | weinan
# Processing Record 22 of Set 7 | khatanga
# Processing Record 23 of Set 7 | pacific grove
# Processing Record 24 of Set 7 | severnoye
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | bridlington
# Processing Record 27 of Set 7 | chihuahua
# Processing Record 28 of Set 7 | chicama
# Processing Record 29 of Set 7 | puerto carreno
# Processing Record 30 of Set 7 | tigil
# Processing Record 31 of Set 7 | green river
# Processing Record 32 of Set 7 | tabuk
# Processing Record 33 of Set 7 | matagami
# Processing Record 34 of Set 7 | puri
# Processing Record 35 of Set 7 | khobi
# Processing Record 36 of Set 7 | esperance
# Processing Record 37 of Set 7 | yarada
# Processing Record 38 of Set 7 | jaen
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | la grande
# Processing Record 41 of Set 7 | mananara
# Processing Record 42 of Set 7 | korla
# Processing Record 43 of Set 7 | nishihara
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | mineros
# Processing Record 46 of Set 7 | barabai
# Processing Record 47 of Set 7 | hinatuan
# Processing Record 48 of Set 7 | colares
# Processing Record 49 of Set 7 | zaysan
# Processing Record 50 of Set 7 | umea
# Processing Record 1 of Set 8 | ngunguru
# Processing Record 2 of Set 8 | eureka
# Processing Record 3 of Set 8 | hay river
# Processing Record 4 of Set 8 | luocheng
# Processing Record 5 of Set 8 | westport
# Processing Record 6 of Set 8 | bafq
# Processing Record 7 of Set 8 | kailua
# Processing Record 8 of Set 8 | la orilla
# Processing Record 9 of Set 8 | sao joao nepomuceno
# Processing Record 10 of Set 8 | banamba
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | tilichiki
# Processing Record 13 of Set 8 | karlskrona
# Processing Record 14 of Set 8 | maraa
# Processing Record 15 of Set 8 | orlik
# Processing Record 16 of Set 8 | maragogi
# Processing Record 17 of Set 8 | magadi
# Processing Record 18 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 19 of Set 8 | cintalapa
# Processing Record 20 of Set 8 | atraulia
# Processing Record 21 of Set 8 | worthington
# Processing Record 22 of Set 8 | yulara
# Processing Record 23 of Set 8 | tynda
# Processing Record 24 of Set 8 | emerald
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | jinchang
# Processing Record 27 of Set 8 | port hardy
# Processing Record 28 of Set 8 | bonavista
# Processing Record 29 of Set 8 | buala
# Processing Record 30 of Set 8 | ocos
# Processing Record 31 of Set 8 | ingham
# Processing Record 32 of Set 8 | chauk
# Processing Record 33 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 34 of Set 8 | aasiaat
# Processing Record 35 of Set 8 | chernukha
# Processing Record 36 of Set 8 | ugoofaaru
# Processing Record 37 of Set 8 | fort nelson
# Processing Record 38 of Set 8 | bontang
# Processing Record 39 of Set 8 | khao yoi
# Processing Record 40 of Set 8 | vetovo
# Processing Record 41 of Set 8 | dingle
# Processing Record 42 of Set 8 | portland
# Processing Record 43 of Set 8 | chama
# Processing Record 44 of Set 8 | gorontalo
# Processing Record 45 of Set 8 | bowen
# Processing Record 46 of Set 8 | port lincoln
# Processing Record 47 of Set 8 | rudnichnyy
# Processing Record 48 of Set 8 | pimenta bueno
# Processing Record 49 of Set 8 | severnyy
# Processing Record 50 of Set 8 | salina cruz
# Processing Record 1 of Set 9 | nicoya
# Processing Record 2 of Set 9 | ahipara
# Processing Record 3 of Set 9 | sao sebastiao
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | gushi
# Processing Record 6 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 9 | ugento
# Processing Record 8 of Set 9 | khasan
# Processing Record 9 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 9 | honningsvag
# Processing Record 11 of Set 9 | talakan
# Processing Record 12 of Set 9 | markova
# Processing Record 13 of Set 9 | naberera
# Processing Record 14 of Set 9 | itarema
# Processing Record 15 of Set 9 | chifeng
# Processing Record 16 of Set 9 | bethel
# Processing Record 17 of Set 9 | susangerd
# Processing Record 18 of Set 9 | kamenskiy
# Processing Record 19 of Set 9 | karlivka
# Processing Record 20 of Set 9 | arua
# Processing Record 21 of Set 9 | bad sooden-allendorf
# Processing Record 22 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 23 of Set 9 | grindavik
# Processing Record 24 of Set 9 | ostrovnoy
# Processing Record 25 of Set 9 | samarai
# Processing Record 26 of Set 9 | mason city
# Processing Record 27 of Set 9 | shellbrook
# Processing Record 28 of Set 9 | varska
# City not found. Skipping...
# Processing Record 29 of Set 9 | santa rosa
# Processing Record 30 of Set 9 | gao
# Processing Record 31 of Set 9 | krasnogorsk
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | cozumel
# Processing Record 34 of Set 9 | tadine
# Processing Record 35 of Set 9 | asau
# Processing Record 36 of Set 9 | duz
# City not found. Skipping...
# Processing Record 37 of Set 9 | palafrugell
# Processing Record 38 of Set 9 | opuwo
# Processing Record 39 of Set 9 | mao
# Processing Record 40 of Set 9 | phan thiet
# Processing Record 41 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 9 | naushki
# Processing Record 43 of Set 9 | coquimbo
# Processing Record 44 of Set 9 | bella vista
# Processing Record 45 of Set 9 | mount pleasant
# Processing Record 46 of Set 9 | sao caetano de odivelas
# Processing Record 47 of Set 9 | nchelenge
# Processing Record 48 of Set 9 | sioux lookout
# Processing Record 49 of Set 9 | nogliki
# Processing Record 50 of Set 9 | lasa
# Processing Record 1 of Set 10 | alofi
# Processing Record 2 of Set 10 | noumea
# Processing Record 3 of Set 10 | kudahuvadhoo
# Processing Record 4 of Set 10 | onokhoy
# Processing Record 5 of Set 10 | high level
# Processing Record 6 of Set 10 | zatoka
# Processing Record 7 of Set 10 | broome
# Processing Record 8 of Set 10 | ambilobe
# Processing Record 9 of Set 10 | salalah
# Processing Record 10 of Set 10 | campbellton
# Processing Record 11 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 10 | yarmouth
# Processing Record 13 of Set 10 | muskegon
# Processing Record 14 of Set 10 | kautokeino
# Processing Record 15 of Set 10 | yar-sale
# Processing Record 16 of Set 10 | opunake
# Processing Record 17 of Set 10 | buraydah
# Processing Record 18 of Set 10 | yaring
# Processing Record 19 of Set 10 | cabedelo
# Processing Record 20 of Set 10 | andros town
# Processing Record 21 of Set 10 | otuzco
# Processing Record 22 of Set 10 | wahiawa
# Processing Record 23 of Set 10 | rosario do sul
# Processing Record 24 of Set 10 | elk point
# Processing Record 25 of Set 10 | saryagash
# Processing Record 26 of Set 10 | kindia
# Processing Record 27 of Set 10 | saint-pierre
# Processing Record 28 of Set 10 | lavras da mangabeira
# Processing Record 29 of Set 10 | ramshir
# Processing Record 30 of Set 10 | isla mujeres
# Processing Record 31 of Set 10 | touros
# Processing Record 32 of Set 10 | talnakh
# Processing Record 33 of Set 10 | san patricio
# Processing Record 34 of Set 10 | adeje
# Processing Record 35 of Set 10 | jaguarari
# Processing Record 36 of Set 10 | eregli
# Processing Record 37 of Set 10 | port-gentil
# Processing Record 38 of Set 10 | teya
# Processing Record 39 of Set 10 | ayagoz
# Processing Record 40 of Set 10 | viedma
# Processing Record 41 of Set 10 | kalabo
# Processing Record 42 of Set 10 | kununurra
# Processing Record 43 of Set 10 | pahrump
# Processing Record 44 of Set 10 | lata
# Processing Record 45 of Set 10 | gweta
# Processing Record 46 of Set 10 | umm kaddadah
# Processing Record 47 of Set 10 | walvis bay
# Processing Record 48 of Set 10 | yumen
# Processing Record 49 of Set 10 | daloa
# Processing Record 50 of Set 10 | ust-ilimsk
# Processing Record 1 of Set 11 | la ronge
# Processing Record 2 of Set 11 | kholtoson
# Processing Record 3 of Set 11 | torbay
# Processing Record 4 of Set 11 | bikaner
# Processing Record 5 of Set 11 | kruisfontein
# Processing Record 6 of Set 11 | los llanos de aridane
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 11 | keshan
# City not found. Skipping...
# Processing Record 11 of Set 11 | meppel
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | ternate
# Processing Record 14 of Set 11 | tura
# Processing Record 15 of Set 11 | saint-augustin
# Processing Record 16 of Set 11 | aniva
# Processing Record 17 of Set 11 | iralaya
# Processing Record 18 of Set 11 | trelew
# Processing Record 19 of Set 11 | camacupa
# Processing Record 20 of Set 11 | nylstroom
# City not found. Skipping...
# Processing Record 21 of Set 11 | picota
# Processing Record 22 of Set 11 | saquena
# Processing Record 23 of Set 11 | zurrieq
# Processing Record 24 of Set 11 | saldanha
# Processing Record 25 of Set 11 | port neches
# Processing Record 26 of Set 11 | maarianhamina
# Processing Record 27 of Set 11 | port blair
# Processing Record 28 of Set 11 | houma
# Processing Record 29 of Set 11 | hell
# Processing Record 30 of Set 11 | el doncello
# Processing Record 31 of Set 11 | srednekolymsk
# Processing Record 32 of Set 11 | zapresic
# Processing Record 33 of Set 11 | port keats
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | bhainsa
# Processing Record 36 of Set 11 | maceio
# Processing Record 37 of Set 11 | santiago de cao
# Processing Record 38 of Set 11 | alekseyevskoye
# Processing Record 39 of Set 11 | luganville
# Processing Record 40 of Set 11 | quatre cocos
# Processing Record 41 of Set 11 | ocampo
# Processing Record 42 of Set 11 | farafangana
# Processing Record 43 of Set 11 | catamarca
# Processing Record 44 of Set 11 | byron bay
# Processing Record 45 of Set 11 | kyabram
# Processing Record 46 of Set 11 | blackwater
# Processing Record 47 of Set 11 | bilma
# Processing Record 48 of Set 11 | tarazona
# Processing Record 49 of Set 11 | ikalamavony
# Processing Record 50 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 1 of Set 12 | tuy hoa
# Processing Record 2 of Set 12 | oshakati
# Processing Record 3 of Set 12 | dembi dolo
# Processing Record 4 of Set 12 | kysyl-syr
# Processing Record 5 of Set 12 | santa maria
# Processing Record 6 of Set 12 | demir kapija
# Processing Record 7 of Set 12 | arcata
# Processing Record 8 of Set 12 | hirara
# Processing Record 9 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 10 of Set 12 | saurimo
# Processing Record 11 of Set 12 | irkutsk
# Processing Record 12 of Set 12 | sao felix do xingu
# Processing Record 13 of Set 12 | ranong
# Processing Record 14 of Set 12 | mapimi
# Processing Record 15 of Set 12 | jurm
# Processing Record 16 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 17 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 12 | xucheng
# Processing Record 19 of Set 12 | luanda
# Processing Record 20 of Set 12 | kihei
# Processing Record 21 of Set 12 | mollendo
# Processing Record 22 of Set 12 | trinidad
# Processing Record 23 of Set 12 | soe
# Processing Record 24 of Set 12 | manzanillo
# Processing Record 25 of Set 12 | ust-nera
# Processing Record 26 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 12 | mecca
# Processing Record 28 of Set 12 | krasnyy chikoy
# Processing Record 29 of Set 12 | strezhevoy
# Processing Record 30 of Set 12 | svetlyy
# Processing Record 31 of Set 12 | kaura namoda
# Processing Record 32 of Set 12 | dawson creek
# Processing Record 33 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 12 | atar
# Processing Record 35 of Set 12 | klaksvik
# Processing Record 36 of Set 12 | chipiona
# Processing Record 37 of Set 12 | kangaatsiaq
# Processing Record 38 of Set 12 | yeniseysk
# Processing Record 39 of Set 12 | cam ranh
# Processing Record 40 of Set 12 | askarovo
# Processing Record 41 of Set 12 | floro
# Processing Record 42 of Set 12 | tchamba
# Processing Record 43 of Set 12 | comodoro rivadavia
# Processing Record 44 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 12 | pringsewu
# Processing Record 46 of Set 12 | ponta delgada
# Processing Record 47 of Set 12 | san lorenzo
# Processing Record 48 of Set 12 | czluchow
# Processing Record 49 of Set 12 | popondetta
# Processing Record 50 of Set 12 | birao
# Processing Record 1 of Set 13 | nemuro
# Processing Record 2 of Set 13 | coihaique
# Processing Record 3 of Set 13 | hauterive
# Processing Record 4 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 13 | kuna
# Processing Record 6 of Set 13 | barra patuca
# Processing Record 7 of Set 13 | caravelas
# Processing Record 8 of Set 13 | koumac
# Processing Record 9 of Set 13 | yurimaguas
# Processing Record 10 of Set 13 | bykovo
# Processing Record 11 of Set 13 | samarinda
# Processing Record 12 of Set 13 | lat yao
# Processing Record 13 of Set 13 | eqbaliyeh
# Processing Record 14 of Set 13 | tsaratanana
# Processing Record 15 of Set 13 | gornopravdinsk
# Processing Record 16 of Set 13 | manacapuru
# Processing Record 17 of Set 13 | broken hill
# Processing Record 18 of Set 13 | kachiry
# Processing Record 19 of Set 13 | banjar
# Processing Record 20 of Set 13 | kamen-na-obi
# Processing Record 21 of Set 13 | khani
# Processing Record 22 of Set 13 | truro
# Processing Record 23 of Set 13 | wangqing
# Processing Record 24 of Set 13 | xingcheng
# Processing Record 25 of Set 13 | tecoanapa
# Processing Record 26 of Set 13 | sioux city
# Processing Record 27 of Set 13 | sangar
# Processing Record 28 of Set 13 | puerto colombia
# Processing Record 29 of Set 13 | maua
# Processing Record 30 of Set 13 | sovetskiy
# Processing Record 31 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 13 | hamilton
# Processing Record 33 of Set 13 | oyonnax
# Processing Record 34 of Set 13 | stovring
# Processing Record 35 of Set 13 | phangnga
# Processing Record 36 of Set 13 | voh
# Processing Record 37 of Set 13 | dumka
# Processing Record 38 of Set 13 | moree
# Processing Record 39 of Set 13 | akyab
# Processing Record 40 of Set 13 | udachnyy
# Processing Record 41 of Set 13 | hofn
# Processing Record 42 of Set 13 | kenai
# Processing Record 43 of Set 13 | lima
# Processing Record 44 of Set 13 | dali
# Processing Record 45 of Set 13 | kulhudhuffushi
# Processing Record 46 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 13 | oussouye
# Processing Record 48 of Set 13 | matay
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | kirovsk
# Processing Record 1 of Set 14 | sikasso
# Processing Record 2 of Set 14 | rudbar
# Processing Record 3 of Set 14 | manono
# Processing Record 4 of Set 14 | chumikan
# Processing Record 5 of Set 14 | fort dodge
# Processing Record 6 of Set 14 | whitianga
# Processing Record 7 of Set 14 | benjamin constant
# Processing Record 8 of Set 14 | tanabe
# Processing Record 9 of Set 14 | vilcun
# Processing Record 10 of Set 14 | punta alta
# Processing Record 11 of Set 14 | sawtell
# Processing Record 12 of Set 14 | sola
# Processing Record 13 of Set 14 | zelenchukskaya
# Processing Record 14 of Set 14 | veraval
# Processing Record 15 of Set 14 | terrace
# Processing Record 16 of Set 14 | sept-iles
# Processing Record 17 of Set 14 | labuhan
# Processing Record 18 of Set 14 | bojnurd
# Processing Record 19 of Set 14 | anadyr
# Processing Record 20 of Set 14 | yenagoa
# Processing Record 21 of Set 14 | tyukalinsk
# Processing Record 22 of Set 14 | praia da vitoria
# Processing Record 23 of Set 14 | singkawang
# Processing Record 24 of Set 14 | dunedin
# Processing Record 25 of Set 14 | mareeba
# Processing Record 26 of Set 14 | tolbazy
# Processing Record 27 of Set 14 | goderich
# Processing Record 28 of Set 14 | north port
# Processing Record 29 of Set 14 | balti
# Processing Record 30 of Set 14 | syamzha
# Processing Record 31 of Set 14 | carlsbad
# Processing Record 32 of Set 14 | bull savanna
# Processing Record 33 of Set 14 | gerzat
# Processing Record 34 of Set 14 | mino
# Processing Record 35 of Set 14 | shebalino
# Processing Record 36 of Set 14 | saint-francois
# Processing Record 37 of Set 14 | imbituba
# Processing Record 38 of Set 14 | raudeberg
# Processing Record 39 of Set 14 | pamanukan
# Processing Record 40 of Set 14 | chatrapur
# Processing Record 41 of Set 14 | bahia honda
# Processing Record 42 of Set 14 | laranjeiras do sul
# Processing Record 43 of Set 14 | yerbogachen
# Processing Record 44 of Set 14 | san jose de sisa
# Processing Record 45 of Set 14 | albi
# Processing Record 46 of Set 14 | morehead
# Processing Record 47 of Set 14 | kostomuksha
# Processing Record 48 of Set 14 | gondanglegi
# Processing Record 49 of Set 14 | palmer
# Processing Record 50 of Set 14 | aktau
# Processing Record 1 of Set 15 | santa maria del oro
# Processing Record 2 of Set 15 | maneromango
# Processing Record 3 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 15 | belyy yar
# Processing Record 5 of Set 15 | poso
# Processing Record 6 of Set 15 | les cayes
# Processing Record 7 of Set 15 | nacala
# Processing Record 8 of Set 15 | murgab
# Processing Record 9 of Set 15 | karratha
# Processing Record 10 of Set 15 | pokhara
# Processing Record 11 of Set 15 | cockburn town
# Processing Record 12 of Set 15 | balikpapan
# Processing Record 13 of Set 15 | tapioszentmarton
# Processing Record 14 of Set 15 | svetlogorsk
# Processing Record 15 of Set 15 | ciudad bolivar
# Processing Record 16 of Set 15 | ambon
# Processing Record 17 of Set 15 | naranjos
# Processing Record 18 of Set 15 | ardakan
# Processing Record 19 of Set 15 | jinka
# Processing Record 20 of Set 15 | guanica
# Processing Record 21 of Set 15 | lazaro cardenas
# Processing Record 22 of Set 15 | cadiz
# Processing Record 23 of Set 15 | scalloway
# City not found. Skipping...
# Processing Record 24 of Set 15 | muros
# Processing Record 25 of Set 15 | buyukcavuslu
# Processing Record 26 of Set 15 | dolinsk
# Processing Record 27 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 15 | smithers
# Processing Record 29 of Set 15 | seoul
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Leningradskiy      RU  69.3833  178.4167     -4.02        97         100
# 1         Ushuaia      AR -54.8000  -68.3000     56.86        38           0
# 2  Saint-Philippe      RE -21.3585   55.7679     76.59        85          58
# 3    Saint George      US  37.1041 -113.5841     36.79        68         100
# 4          Dabhol      IN  17.6000   73.1667     75.33        64          22
# 5     Tuktoyaktuk      CA  69.4541 -133.0374      1.40        85          40
# 6      Butaritari      KI   3.0707  172.7902     79.56        74         100
# 7          Atuona      PF  -9.8000 -139.0333     77.86        70           5
# 8        Petatlan      MX  17.5167 -101.2667     76.80        76          18
# 9  Vestmannaeyjar      IS  63.4427  -20.2734     49.19        93         100
#
#    Wind Speed Current Description
# 0        5.30     overcast clouds
# 1        5.75           clear sky
# 2       13.40          light rain
# 3        3.44     overcast clouds
# 4        6.33          few clouds
# 5        5.75    scattered clouds
# 6       10.54     overcast clouds
# 7       18.52           clear sky
# 8        0.29          few clouds
# 9       40.29                mist

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "../Weather_Database/WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
